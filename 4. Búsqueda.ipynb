# %%
import pandas as pd

# %%
df = pd.read_csv(('empleados.csv'), delimiter=";")

# %%
df
# Out:
#         Nombre  Apellido       Sexo   Estado_Civil  Edad  Experiencia  \
# 0    Alexandro       NaN  Masculino     Soltero(a)  22.0          3.0
# 1       Carlos       NaN  Masculino      Casado(a)  38.0         10.0
# 2       Felipa       NaN   Femenino     Soltero(a)  26.0          5.0
# 3       Daniel       NaN  Masculino      Casado(a)  35.0         10.0
# 4         John       NaN  Masculino      Casado(a)  35.0         13.0
# ..         ...       ...        ...            ...   ...          ...
# 246       Jose       NaN  Masculino      Casado(a)  30.0          6.0
# 247    Marcelo       NaN  Masculino  Divorciado(a)  44.0         15.0
# 248       Eric       NaN        NaN      Casado(a)  25.0          7.0
# 249       Marc       NaN        NaN      Casado(a)  24.0          2.0
# 250    Leandro       NaN  Masculino      Casado(a)  37.0         11.0
#
#      Salario Gerencia          Departamento
# 0     2423.0       No            Publicidad
# ...

# %%
df['Edad']= df['Edad'].fillna(df['Edad'].mean())

# %%
df.head(50)
# Out:
#        Nombre  Apellido       Sexo   Estado_Civil       Edad  Experiencia  \
# 0   Alexandro       NaN  Masculino     Soltero(a)  22.000000          3.0
# 1      Carlos       NaN  Masculino      Casado(a)  38.000000         10.0
# 2      Felipa       NaN   Femenino     Soltero(a)  26.000000          5.0
# 3      Daniel       NaN  Masculino      Casado(a)  35.000000         10.0
# 4        John       NaN  Masculino      Casado(a)  35.000000         13.0
# 5      Edward       NaN  Masculino     Soltero(a)  33.331579          NaN
# 6     Ruperta       NaN   Femenino      Casado(a)  54.000000         18.0
# 7       Amaya       NaN   Femenino  Divorciado(a)  22.000000          3.0
# 8   Francisca       NaN   Femenino     Soltero(a)  27.000000          4.0
# 9      Selena       NaN   Femenino      Casado(a)  24.000000          6.0
# 10       Febe       NaN   Femenino      Casado(a)  44.000000         22.0
# 11     Ximena       NaN   Femenino     Soltero(a)  58.000000         24.0
# ...

# %%
busqueda2= "Vera"

busqueda3= df[df['Nombre']==busqueda2]
print(busqueda3)
# Out:
#    Nombre  Apellido Sexo Estado_Civil       Edad  Experiencia  Salario  \
# 32   Vera       NaN  NaN    Casado(a)  33.331579          NaN      NaN
#
#    Gerencia Departamento
# 32      NaN          NaN
