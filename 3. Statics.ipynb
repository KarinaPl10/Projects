# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('temperaturas.csv', delimiter=";")

# %%
df.describe()
# Out:
#                Año  temperatura
# count    62.000000    62.000000
# mean   1990.500000    72.624194
# std      18.041619     1.057322
# min    1960.000000    70.900000
# 25%    1975.250000    71.725000
# 50%    1990.500000    72.450000
# 75%    2005.750000    73.300000
# max    2021.000000    75.300000

# %%
df.min()
# Out:
# Año            1960.0
# temperatura      70.9
# dtype: float64

# %%
df.max()
# Out:
# Año            2021.0
# temperatura      75.3
# dtype: float64

# %%
df.var()
# Out:
# Año            325.50000
# temperatura      1.11793
# dtype: float64

# %%
df.std()
# Out:
# Año            18.041619
# temperatura     1.057322
# dtype: float64
